# %% [markdown]
# #### <b>Objective:</b> Token Classification

# %% [markdown]
# #### About Dataset:
# *  <b>Dataset:</b> [FUNSD - Form Understanding in Noisy Scanned Documents](https://guillaumejaume.github.io/FUNSD/) <br>
# FUNSD paper: https://arxiv.org/abs/1905.13538
#  * The dataset comprises 199 real, fully annotated, scanned forms.
#  *  Labels:
#     1.   question
#     2.   answer
#     3.   header
#     4.   other

# %% [markdown]
# ## Install Necesities

# %% [markdown]
# ##### Library introduction:
# 1.   unilm -  **Uni**fied pre-trained **L**anguage **M**odel:
#         * for pre-processing
#         * also includes layoutlm model
#
# 2.  Transformer
#       * Here, we're cloning it separately so that it can update the outdated transformers package that is included in the unilm package.

# %%
# ! rm -r unilm
# ! git clone -b remove_torch_save https://github.com/NielsRogge/unilm.git
# ! cd unilm/layoutlm
# ! pip install unilm/layoutlm

# %%
# ! rm -r transformers
# ! git clone https://github.com/huggingface/transformers.git
# ! cd transformers
# ! pip install ./transformers

# %% [markdown]
# ####  Downloading the dataset
# * gives png and json files

# %%
# ! wget https://guillaumejaume.github.io/FUNSD/dataset.zip
# ! unzip dataset.zip && mv dataset data && rm -rf dataset.zip __MACOSX

# %% [markdown]
# #### View sample Image

# %%
from PIL import Image, ImageDraw, ImageFont

image = Image.open("path to your folder/data/training_data/images/0000971160.png")
image = image.convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=762x1000>

# %% [markdown]
# #### View image with annotations

# %% [markdown]
# #### Json understanding:
# It includes coordinates with corresponding labels. Further, it also includes sub words that are added inside that particular label.
# example:
#
# qip.in is labeled as other.
# so json contains, overall bounding box co-ordinates for qip.in. And addition to that it also contains co-ordinates for qip, . and in separately.

# %%
import json

with open('path to your folder/data/training_data/annotations/0000971160.json') as f:
  data = json.load(f)

for annotation in data['form']:
  print(annotation)
# Out:
# {'box': [292, 91, 376, 175], 'text': 'R&D', 'label': 'other', 'words': [{'box': [292, 91, 376, 175], 'text': 'R&D'}], 'linking': [], 'id': 0}
# {'box': [219, 316, 225, 327], 'text': ':', 'label': 'question', 'words': [{'box': [219, 316, 225, 327], 'text': ':'}], 'linking': [], 'id': 1}
# {'box': [95, 355, 169, 370], 'text': 'Suggestion:', 'label': 'question', 'words': [{'box': [95, 355, 169, 370], 'text': 'Suggestion:'}], 'linking': [[2, 16]], 'id': 2}
# {'box': [482, 268, 518, 282], 'text': 'Date:', 'label': 'question', 'words': [{'box': [482, 268, 518, 282], 'text': 'Date:'}], 'linking': [[3, 12]], 'id': 3}
# {'box': [511, 309, 570, 323], 'text': 'Licensee', 'label': 'answer', 'words': [{'box': [511, 309, 570, 323], 'text': 'Licensee'}], 'linking': [[13, 4]], 'id': 4}
# {'box': [211, 651, 217, 662], 'text': '', 'label': 'question', 'words': [{'box': [211, 651, 217, 662], 'text': ''}], 'linking': [], 'id': 5}
# {'box': [461, 605, 483, 619], 'text': 'Yes', 'label': 'question', 'words': [{'box': [461, 605, 483, 619], 'text': 'Yes'}], 'linking': [[19, 6]], 'id': 6}
# {'box': [545, 603, 563, 617], 'text': 'No', 'label': 'question', 'words': [{'box': [545, 603, 563, 617], 'text': 'No'}], 'linking': [[19, 7]], 'id': 7}
# {'box': [525, 904, 641, 926], 'text': '597005708', 'label': 'other', 'words': [{'box': [525, 904, 641, 926], 'text': '597005708'}], 'linking': [], 'id': 8}
# {'text': 'R&D QUALITY IMPROVEMENT SUGGESTION/ SOLUTION FORM', 'box': [256, 201, 423, 230], 'linking': [], 'label': 'header', 'words': [{'text': 'R&D', 'box': [257, 203, 279, 214]}, {'text': 'QUALITY', 'box': [285, 203, 334, 216]}, {'text': 'IMPROVEMENT', 'box': [341, 201, 418, 211]}, {'text': 'SUGGESTION/', 'box': [256, 215, 324, 229]}, {'text': '', 'box': [324, 216, 332, 230]}, {'text': 'SOLUTION', 'box': [331, 214, 387, 228]}, {'text': 'FORM', 'box': [395, 215, 423, 228]}], 'id': 9}
# {'text': 'Name / Phone Ext. :', 'box': [89, 272, 204, 289], 'linking': [[10, 11]], 'label': 'question', 'words': [{'text': 'Name', 'box': [89, 274, 118, 289]}, {'text': '/', 'box': [117, 274, 127, 288]}, {'text': 'Phone', 'box': [128, 274, 163, 289]}, {'text': 'Ext.', 'box': [169, 272, 196, 287]}, {'text': ':', 'box': [196, 274, 204, 288]}], 'id': 10}
# {'text': 'M. Hamann P. Harper, P. Martinez', 'box': [215, 271, 451, 287], 'linking': [[10, 11]], 'label': 'answer', 'words': [{'text': 'M.', 'box': [215, 272, 230, 287]}, {'text': 'Hamann', 'box': [237, 272, 287, 286]}, {'text': 'P.', 'box': [293, 272, 307, 286]}, {'text': 'Harper,', 'box': [314, 274, 363, 285]}, {'text': 'P.', 'box': [370, 272, 384, 285]}, {'text': 'Martinez', 'box': [390, 271, 451, 282]}], 'id': 11}
# {'text': '9/ 3/ 92', 'box': [543, 264, 590, 279], 'linking': [[3, 12]], 'label': 'answer', 'words': [{'text': '9/', 'box': [543, 265, 560, 279]}, {'text': '3/', 'box': [560, 264, 575, 279]}, {'text': '92', 'box': [575, 264, 590, 279]}], 'id': 12}
# {'text': 'R&D Group:', 'box': [420, 310, 491, 323], 'linking': [[13, 4]], 'label': 'question', 'words': [{'text': 'R&D', 'box': [420, 310, 442, 323]}, {'text': 'Group:', 'box': [448, 310, 491, 323]}], 'id': 13}
# {'text': 'J. S. Wigand', 'box': [236, 313, 327, 327], 'linking': [[15, 14]], 'label': 'answer', 'words': [{'text': 'J.', 'box': [236, 313, 251, 327]}, {'text': 'S.', 'box': [256, 313, 273, 326]}, {'text': 'Wigand', 'box': [278, 313, 327, 327]}], 'id': 14}
# {'text': 'Supervisor / Manager', 'box': [91, 316, 218, 331], 'linking': [[15, 14]], 'label': 'question', 'words': [{'text': 'Supervisor', 'box': [91, 316, 161, 330]}, {'text': '/', 'box': [163, 318, 169, 331]}, {'text': 'Manager', 'box': [169, 317, 218, 327]}], 'id': 15}
# {'text': 'Discontinue coal retention analyses on licensee submitted product samples (Note : Coal Retention testing is not performed by most licensees. Other B&W physical measurements as ends stability and inspection for soft spots in ciparettes are thought to be sufficient measures to assure cigarette physical integrity. The proposed action will increase laboratory productivity . )', 'box': [190, 346, 594, 447], 'linking': [[2, 16]], 'label': 'answer', 'words': [{'text': 'Discontinue', 'box': [190, 355, 268, 366]}, {'text': 'coal', 'box': [274, 353, 303, 366]}, {'text': 'retention', 'box': [309, 352, 375, 365]}, {'text': 'analyses', 'box': [381, 351, 435, 365]}, {'text': 'on', 'box': [443, 352, 458, 363]}, {'text': 'licensee', 'box': [464, 348, 520, 362]}, {'text': 'submitted', 'box': [527, 346, 594, 361]}, {'text': 'product', 'box': [190, 369, 240, 383]}, {'text': 'samples', 'box': [247, 367, 301, 380]}, {'text': '(Note', 'box': [318, 365, 352, 379]}, {'text': ':', 'box': [352, 367, 359, 380]}, {'text': 'Coal', 'box': [373, 366, 402, 376]}, {'text': 'Retention', 'box': [408, 366, 472, 376]}, {'text': 'testing', 'box': [479, 365, 529, 376]}, {'text': 'is', 'box': [536, 363, 549, 374]}, {'text': 'not', 'box': [554, 363, 578, 374]}, {'text': 'performed', 'box': [190, 383, 256, 394]}, {'text': 'by', 'box': [261, 381, 275, 394]}, {'text': 'most', 'box': [282, 383, 311, 393]}, {'text': 'licensees.', 'box': [318, 380, 386, 391]}, {'text': 'Other', 'box': [401, 378, 437, 389]}, {'text': 'B&W', 'box': [443, 378, 465, 389]}, {'text': 'physical', 'box': [471, 377, 528, 391]}, {'text': 'measurements', 'box': [191, 398, 275, 406]}, {'text': 'as', 'box': [282, 397, 297, 405]}, {'text': 'ends', 'box': [304, 394, 332, 405]}, {'text': 'stability', 'box': [339, 394, 402, 405]}, {'text': 'and', 'box': [409, 392, 430, 402]}, {'text': 'inspection', 'box': [437, 392, 508, 403]}, {'text': 'for', 'box': [515, 391, 535, 402]}, {'text': 'soft', 'box': [542, 391, 571, 401]}, {'text': 'spots', 'box': [193, 411, 228, 422]}, {'text': 'in', 'box': [235, 409, 250, 420]}, {'text': 'ciparettes', 'box': [256, 409, 327, 419]}, {'text': 'are', 'box': [332, 408, 352, 418]}, {'text': 'thought', 'box': [360, 406, 410, 419]}, {'text': 'to', 'box': [415, 406, 430, 416]}, {'text': 'be', 'box': [436, 404, 453, 417]}, {'text': 'sufficient', 'box': [458, 405, 529, 415]}, {'text': 'measures', 'box': [535, 405, 592, 415]}, {'text': 'to', 'box': [193, 425, 208, 433]}, {'text': 'assure', 'box': [214, 423, 255, 431]}, {'text': 'cigarette', 'box': [261, 420, 325, 434]}, {'text': 'physical', 'box': [331, 419, 390, 432]}, {'text': 'integrity.', 'box': [395, 418, 463, 431]}, {'text': 'The', 'box': [478, 416, 500, 429]}, {'text': 'proposed', 'box': [506, 418, 566, 431]}, {'text': 'action', 'box': [193, 436, 236, 447]}, {'text': 'will', 'box': [240, 436, 269, 447]}, {'text': 'increase', 'box': [277, 434, 333, 445]}, {'text': 'laboratory', 'box': [339, 433, 410, 446]}, {'text': 'productivity', 'box': [418, 430, 502, 445]}, {'text': '.', 'box': [503, 433, 507, 444]}, {'text': ')', 'box': [508, 430, 514, 444]}], 'id': 16}
# {'text': 'Suggested Solutions (s) :', 'box': [95, 486, 250, 504], 'linking': [[17, 18]], 'label': 'question', 'words': [{'text': 'Suggested', 'box': [95, 489, 159, 504]}, {'text': 'Solutions', 'box': [165, 487, 222, 501]}, {'text': '(s)', 'box': [223, 486, 241, 503]}, {'text': ':', 'box': [243, 489, 250, 503]}], 'id': 17}
# {'text': 'Delete coal retention from the list of standard analyses performed on licensee submitted product samples. Special requests for coal retention testing could still be submitted on an exception basis.', 'box': [263, 483, 593, 553], 'linking': [[17, 18]], 'label': 'answer', 'words': [{'text': 'Delete', 'box': [263, 486, 306, 500]}, {'text': 'coal', 'box': [313, 486, 341, 499]}, {'text': 'retention', 'box': [348, 486, 412, 497]}, {'text': 'from', 'box': [416, 485, 447, 498]}, {'text': 'the', 'box': [453, 485, 475, 498]}, {'text': 'list', 'box': [480, 483, 508, 496]}, {'text': 'of', 'box': [515, 483, 532, 494]}, {'text': 'standard', 'box': [536, 483, 593, 494]}, {'text': 'analyses', 'box': [264, 501, 320, 514]}, {'text': 'performed', 'box': [324, 501, 392, 512]}, {'text': 'on', 'box': [397, 501, 412, 511]}, {'text': 'licensee', 'box': [419, 499, 475, 512]}, {'text': 'submitted', 'box': [482, 499, 546, 510]}, {'text': 'product', 'box': [264, 517, 314, 528]}, {'text': 'samples.', 'box': [320, 514, 374, 528]}, {'text': 'Special', 'box': [390, 513, 439, 526]}, {'text': 'requests', 'box': [446, 513, 502, 524]}, {'text': 'for', 'box': [508, 511, 530, 522]}, {'text': 'coal', 'box': [538, 510, 566, 523]}, {'text': 'retention', 'box': [263, 529, 330, 540]}, {'text': 'testing', 'box': [335, 527, 387, 540]}, {'text': 'could', 'box': [390, 527, 428, 538]}, {'text': 'still', 'box': [433, 525, 468, 536]}, {'text': 'be', 'box': [473, 525, 488, 535]}, {'text': 'submitted', 'box': [496, 524, 560, 537]}, {'text': 'on', 'box': [566, 524, 584, 537]}, {'text': 'an', 'box': [264, 543, 281, 553]}, {'text': 'exception', 'box': [286, 539, 350, 553]}, {'text': 'basis.', 'box': [355, 541, 397, 551]}], 'id': 18}
# {'text': 'Have you contacted your Manager/ Supervisor?', 'box': [96, 608, 398, 624], 'linking': [[19, 6], [19, 7]], 'label': 'header', 'words': [{'text': 'Have', 'box': [96, 612, 127, 623]}, {'text': 'you', 'box': [131, 613, 156, 624]}, {'text': 'contacted', 'box': [161, 612, 225, 623]}, {'text': 'your', 'box': [229, 610, 260, 623]}, {'text': 'Manager/', 'box': [264, 609, 314, 622]}, {'text': '', 'box': [314, 608, 322, 622]}, {'text': 'Supervisor?', 'box': [323, 608, 398, 621]}], 'id': 19}
# {'text': 'Manager Comments:', 'box': [98, 651, 211, 665], 'linking': [[20, 21], [20, 22]], 'label': 'question', 'words': [{'text': 'Manager', 'box': [98, 654, 150, 665]}, {'text': 'Comments:', 'box': [154, 651, 211, 664]}], 'id': 20}
# {'text': 'Manager, please contact suggester and forward', 'box': [232, 644, 547, 662], 'linking': [[20, 21]], 'label': 'answer', 'words': [{'text': 'Manager,', 'box': [232, 648, 288, 662]}, {'text': 'please', 'box': [296, 649, 338, 662]}, {'text': 'contact', 'box': [344, 648, 394, 662]}, {'text': 'suggester', 'box': [401, 648, 464, 661]}, {'text': 'and', 'box': [469, 647, 491, 658]}, {'text': 'forward', 'box': [497, 644, 547, 657]}], 'id': 21}
# {'text': 'comments to the Quality Council.', 'box': [99, 662, 323, 677], 'linking': [[20, 22]], 'label': 'answer', 'words': [{'text': 'comments', 'box': [99, 666, 155, 677]}, {'text': 'to', 'box': [162, 665, 177, 676]}, {'text': 'the', 'box': [183, 665, 205, 675]}, {'text': 'Quality', 'box': [211, 663, 261, 676]}, {'text': 'Council.', 'box': [267, 662, 323, 676]}], 'id': 22}
# {'text': 'qip . wp', 'box': [102, 823, 145, 838], 'linking': [], 'label': 'other', 'words': [{'text': 'qip', 'box': [102, 824, 123, 837]}, {'text': '.', 'box': [124, 824, 130, 838]}, {'text': 'wp', 'box': [130, 823, 145, 837]}], 'id': 23}

# %% [markdown]
# The PIL library has a handy ImageDraw module, which -you guessed it- allows to draw things (such as rectangles) on an image:

# %%
draw = ImageDraw.Draw(image, "RGBA")

font = ImageFont.load_default()

label2color = {'question':'blue', 'answer':'green', 'header':'orange', 'other':'violet'}

for annotation in data['form']:
  label = annotation['label']
  general_box = annotation['box']
  draw.rectangle(general_box, outline=label2color[label], width=2)
  draw.text((general_box[0] + 10, general_box[1] - 10), label, fill=label2color[label], font=font)
  words = annotation['words']
  for word in words:
    box = word['box']
    draw.rectangle(box, outline=label2color[label], width=1)

image
# Out:
# <PIL.Image.Image image mode=RGB size=762x1000>

# %% [markdown]
# ## Preprocessing the data
#
# Next, we need to turn the document images into individual tokens and corresponding labels (BIOES format, see further). We do this both for the training and test datasets. Make sure to run this from the `/content` directory:

# %%
! python unilm/layoutlm/examples/seq_labeling/preprocess.py --data_dir data/training_data/annotations \
                                                      --data_split train \
                                                      --output_dir data \
                                                      --model_name_or_path microsoft/layoutlm-base-uncased \
                                                      --max_len 510

! python unilm/layoutlm/examples/seq_labeling/preprocess.py --data_dir data/testing_data/annotations \
                                                      --data_split test \
                                                      --output_dir data \
                                                      --model_name_or_path microsoft/layoutlm-base-uncased \
                                                      --max_len 510
# Out:
# tokenizer_config.json: 100% 170/170 [00:00<00:00, 512kB/s]
# config.json: 100% 606/606 [00:00<00:00, 2.46MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 3.21MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 3.55MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 465kB/s]

# %% [markdown]
# Next, we create a labels.txt file that contains the unique labels of the FUNSD dataset:

# %%
'''this command reads the train.txt file, extracts the second column, removes empty lines, 
sorts the labels alphabetically, removes duplicate labels, 
and saves the unique sorted labels to a file named labels.txt in the data directory.'''
! cat data/train.txt | cut -d$'\t' -f 2 | grep -v "^$"| sort | uniq > data/labels.txt

# %% [markdown]
# ## Define a PyTorch dataset
#
# First, we create a list containing the unique labels based on `data/labels.txt` (run this from the content directory):

# %%
from torch.nn import CrossEntropyLoss

def get_labels(path):
    with open(path, "r") as f:
        labels = f.read().splitlines()
    if "O" not in labels:
        labels = ["O"] + labels
    return labels

labels = get_labels("data/labels.txt")
num_labels = len(labels)
label_map = {i: label for i, label in enumerate(labels)}
# Use cross entropy ignore index as padding label id so that only real label ids contribute to the loss later
pad_token_label_id = CrossEntropyLoss().ignore_index

# %% [markdown]
# We can see that the dataset uses the so-called BIOES annotation scheme to annotate the tokens. This means that a given token can be either at the beginning (B), inside (I), outside (O), at the end (E) or start (S) of a given entity. Entities include ANSWER, QUESTION, HEADER and OTHER:

# %%
print(labels)
# Out:
# ['B-ANSWER', 'B-HEADER', 'B-QUESTION', 'E-ANSWER', 'E-HEADER', 'E-QUESTION', 'I-ANSWER', 'I-HEADER', 'I-QUESTION', 'O', 'S-ANSWER', 'S-HEADER', 'S-QUESTION']

# %% [markdown]
# Next, we can create a PyTorch dataset and corresponding dataloader (both for training and evaluation):

# %%
from transformers import LayoutLMTokenizer
from unilm.layoutlm.layoutlm.data.funsd import FunsdDataset, InputFeatures
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

args = {'local_rank': -1,
        'overwrite_cache': True,
        'data_dir': '/content/data',
        'model_name_or_path':'microsoft/layoutlm-base-uncased',
        'max_seq_length': 512,
        'model_type': 'layoutlm',}

# class to turn the keys of a dict into attributes (thanks Stackoverflow)
class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self

args = AttrDict(args)

tokenizer = LayoutLMTokenizer.from_pretrained("microsoft/layoutlm-base-uncased")

# the LayoutLM authors already defined a specific FunsdDataset, so we are going to use this here
train_dataset = FunsdDataset(args, tokenizer, labels, pad_token_label_id, mode="train")
train_sampler = RandomSampler(train_dataset)
train_dataloader = DataLoader(train_dataset,
                              sampler=train_sampler,
                              batch_size=2)

eval_dataset = FunsdDataset(args, tokenizer, labels, pad_token_label_id, mode="test")
eval_sampler = SequentialSampler(eval_dataset)
eval_dataloader = DataLoader(eval_dataset,
                             sampler=eval_sampler,
                            batch_size=2)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
len(train_dataloader)
# Out:
# 75

# %%
len(eval_dataloader)
# Out:
# 26

# %%
batch = next(iter(train_dataloader))
input_ids = batch[0][0]
tokenizer.decode(input_ids)
# Out:
# '[CLS] description design no 272972 [UNK] use : official [UNK] domestic [UNK] ( gravure ) no [UNK] branch replacement louisville petersburg macon description branch louisville petersburg 80 - 15 272972 comments : macon 680115980 qned : date : brown & williamson tobacco corporation material specification design change authorization new item viceroy rich lights 100\'s 20\'s label brand ( s ) viceroy rich lights b1 - 257 upc no material no. 50 - 034a type change : [UNK] temporary military [UNK] export general [UNK] export customer spec. if a material or dimensional change also involved? if yes supply details [UNK] yes winston salem 10 / 16 / 81 1010 / 30 / 8181 schedule : date or inventory depletion delivery date viceroy rich lights 100\'s 20\'s label design no. upc no. material no 50 - 034 winston salem inventory depletion date 10 / 30 / 81 material # 50 - 034 a has been assigned to the viceroy rich lights 100\'s 20\'s label with new bottom panel. bottom now incorporates shield. on both side and bottom panels, " viceroy " and " rich lights " have been inverted. cartons and labels must change design simultaneously. the current design cannot be used in production after 10 / 30 / 81. j. f. banks c. lamb c. l. domeck webb l. c. lanham branch qc branch supply copies to : s. t. beasley ( mrs ) / jlf 9 / 17 / 8181 680115980 produced from b & w web site [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]'

# %% [markdown]
# ## Define and fine-tune the model
#
# As this is a sequence labeling task, we are going to load `LayoutLMForTokenClassification` (the base sized model) from the hub. We are going to fine-tune it on a downstream task, namely FUNSD.

# %%
from transformers import LayoutLMForTokenClassification
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = LayoutLMForTokenClassification.from_pretrained("microsoft/layoutlm-base-uncased", num_labels=num_labels)
model.to(device)
# Out:
# model.safetensors:   0%|          | 0.00/451M [00:00<?, ?B/s]
# Some weights of LayoutLMForTokenClassification were not initialized from the model checkpoint at microsoft/layoutlm-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# LayoutLMForTokenClassification(
#   (layoutlm): LayoutLMModel(
#     (embeddings): LayoutLMEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (x_position_embeddings): Embedding(1024, 768)
#       (y_position_embeddings): Embedding(1024, 768)
#       (h_position_embeddings): Embedding(1024, 768)
#       (w_position_embeddings): Embedding(1024, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): LayoutLMEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x LayoutLMLayer(
#           (attention): LayoutLMAttention(
#             (self): LayoutLMSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LayoutLMSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LayoutLMIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): LayoutLMOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): LayoutLMPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=13, bias=True)
# )

# %% [markdown]
# Now we can start training:

# %%
from transformers import AdamW
from tqdm import tqdm

optimizer = AdamW(model.parameters(), lr=5e-5)

global_step = 0
num_train_epochs = 5
t_total = len(train_dataloader) * num_train_epochs # total number of training steps

#put the model in training mode
model.train()
for epoch in range(num_train_epochs):
  for batch in tqdm(train_dataloader, desc="Training"):
      input_ids = batch[0].to(device)
      bbox = batch[4].to(device)
      attention_mask = batch[1].to(device)
      token_type_ids = batch[2].to(device)
      labels = batch[3].to(device)

      # forward pass
      outputs = model(input_ids=input_ids, bbox=bbox, attention_mask=attention_mask, token_type_ids=token_type_ids,
                      labels=labels)
      loss = outputs.loss

      # print loss every 100 steps
      if global_step % 100 == 0:
        print(f"Loss after {global_step} steps: {loss.item()}")

      # backward pass to get the gradients
      loss.backward()

      #print("Gradients on classification head:")
      #print(model.classifier.weight.grad[6,:].sum())

      # update
      optimizer.step()
      optimizer.zero_grad()
      global_step += 1
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Training:   0%|          | 0/75 [00:00<?, ?it/s]
# Loss after 0 steps: 2.5504631996154785
# Training: 100%|██████████| 75/75 [14:31<00:00, 11.62s/it]
# Training:  33%|███▎      | 25/75 [04:47<09:44, 11.68s/it]
# Loss after 100 steps: 0.953654944896698
# Training: 100%|██████████| 75/75 [14:16<00:00, 11.42s/it]
# Training:  67%|██████▋   | 50/75 [09:32<04:51, 11.66s/it]
# Loss after 200 steps: 0.19795499742031097
# Training: 100%|██████████| 75/75 [14:19<00:00, 11.45s/it]
# Training: 100%|██████████| 75/75 [14:22<00:00, 11.50s/it]
# Training:   0%|          | 0/75 [00:00<?, ?it/s]
# Loss after 300 steps: 0.21473243832588196
# Training: 100%|██████████| 75/75 [14:27<00:00, 11.56s/it]

# %% [markdown]
# ## Evaluation
#
# Now let's evaluate on the test set:

# %%
# !pip install seqeval
# Out:
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.4.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=e0a1ddc8a050dbda7026dd584d813ce796933824d1e99752b6193856757ce88d
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
import numpy as np
from seqeval.metrics import (
    classification_report,
    f1_score,
    precision_score,
    recall_score,
)

eval_loss = 0.0
nb_eval_steps = 0
preds = None
out_label_ids = None

# put model in evaluation mode
model.eval()
for batch in tqdm(eval_dataloader, desc="Evaluating"):
    with torch.no_grad():
        input_ids = batch[0].to(device)
        bbox = batch[4].to(device)
        attention_mask = batch[1].to(device)
        token_type_ids = batch[2].to(device)
        labels = batch[3].to(device)

        # forward pass
        outputs = model(input_ids=input_ids, bbox=bbox, attention_mask=attention_mask, token_type_ids=token_type_ids,
                        labels=labels)
        # get the loss and logits
        tmp_eval_loss = outputs.loss
        logits = outputs.logits

        eval_loss += tmp_eval_loss.item()
        nb_eval_steps += 1

        # compute the predictions
        if preds is None:
            preds = logits.detach().cpu().numpy()
            out_label_ids = labels.detach().cpu().numpy()
        else:
            preds = np.append(preds, logits.detach().cpu().numpy(), axis=0)
            out_label_ids = np.append(
                out_label_ids, labels.detach().cpu().numpy(), axis=0
            )

# compute average evaluation loss
eval_loss = eval_loss / nb_eval_steps
preds = np.argmax(preds, axis=2)

out_label_list = [[] for _ in range(out_label_ids.shape[0])]
preds_list = [[] for _ in range(out_label_ids.shape[0])]

for i in range(out_label_ids.shape[0]):
    for j in range(out_label_ids.shape[1]):
        if out_label_ids[i, j] != pad_token_label_id:
            out_label_list[i].append(label_map[out_label_ids[i][j]])
            preds_list[i].append(label_map[preds[i][j]])

results = {
    "loss": eval_loss,
    "precision": precision_score(out_label_list, preds_list),
    "recall": recall_score(out_label_list, preds_list),
    "f1": f1_score(out_label_list, preds_list),
}
print(results)
# Out:
# Evaluating: 100%|██████████| 26/26 [01:50<00:00,  4.25s/it]
# {'loss': 1.1345821011524935, 'precision': 0.7013113161728994, 'recall': 0.7223611805902952, 'f1': 0.7116806308526368}

# %%
PATH='./layoutlm.pt'
torch.save(model.state_dict(), PATH)

# %% [markdown]
# ## Inference
#
# Now comes the fun part! We can now use the fine-tuned model and test it on unseen data.
#
# Note that LayoutLM relies on an external OCR engine (it's not end-to-end -> that's probably something for the future). The test data itself also contains the annotated bounding boxes, but let's run an OCR engine ourselves.
#
# So let's load in a image of the test set, run our own OCR on it to get the bounding boxes, then run LayoutLM on the individual tokens and visualize the result!
#
# Sources:
# * https://www.kaggle.com/jpmiller/layoutlm-starter
# * https://bhadreshpsavani.medium.com/how-to-use-tesseract-library-for-ocr-in-google-colab-notebook-5da5470e4fe0

# %%
# !git clone https://github.com/UBIAI/layout_lm_tutorial.git
# Out:
# Cloning into 'layout_lm_tutorial'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), done.

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (5,440 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (24.0)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (9.4.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10

# %%
from layout_lm_tutorial.layoutlm_preprocess import *
import pytesseract

# %%
from PIL import Image

# %%
image = Image.open("/content/data/testing_data/images/82092117.png")
image = image.convert("RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=754x1000>

# %%
model_path='/content/layoutlm.pt'
model=model_load(model_path,num_labels)
image, words, boxes, actual_boxes = preprocess("/content/data/testing_data/images/83443897.png")

word_level_predictions, final_boxes=convert_to_features(image, words, boxes, actual_boxes, model)
# Out:
# Some weights of LayoutLMForTokenClassification were not initialized from the model checkpoint at microsoft/layoutlm-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 1, 7, 7, 9, 9, 9, 9, 9, 9, 9, 9, 9, 12, 12, 0, 6, 6, 3, 2, 5, 5, 10, 10, 10, 10, 10, 3, 3, 3, 2, 8, 5, 5, 0, 3, 3, 2, 5, 0, 0, 6, 6, 6, 3, 2, 8, 5, 5, 5, 0, 6, 9, 3, 3, 3, 3, 2, 5, 0, 6, 9, 3, 3, 3, 3, 12, 5, 0, 3, 6, 6, 6, 6, 3, 3, 2, 5, 0, 6, 6, 6, 6, 6, 6, 6, 6, 6, 3, 3, 3, 3, 3, 2, 8, 8, 8, 5, 5, 5, 0, 0, 9, 6, 2, 8, 8, 5, 5, 12, 9, 9, 9, 9, 9, 9, 9, 9, 1, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 6, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 1, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 1, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 1, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 7, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9]

# %%
draw = ImageDraw.Draw(image)
font = ImageFont.load_default()
def iob_to_label(label):
  if label != 'O':
    return label[2:]
  else:
    return ""
label2color = {'question':'blue', 'answer':'green', 'header':'orange', '':'violet'}
for prediction, box in zip(word_level_predictions, final_boxes):
    predicted_label = iob_to_label(label_map[prediction]).lower()
    draw.rectangle(box, outline=label2color[predicted_label])
    draw.text((box[0] + 10, box[1] - 10), text=predicted_label, fill=label2color[predicted_label], font=font)
image
# Out:
# <PIL.Image.Image image mode=RGB size=754x1000>

# %%
# !zip -r /content/file.zip /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/transformers/.github/conda/meta.yaml (deflated 55%)
#   adding: content/transformers/.github/PULL_REQUEST_TEMPLATE.md (deflated 52%)
#   adding: content/transformers/.github/actions/ (stored 0%)
#   adding: content/transformers/.github/actions/post-slack/ (stored 0%)
#   adding: content/transformers/.github/actions/post-slack/action.yml (deflated 67%)
#   adding: content/transformers/.github/ISSUE_TEMPLATE/ (stored 0%)
#   adding: content/transformers/.github/ISSUE_TEMPLATE/feature-request.yml (deflated 56%)
#   adding: content/transformers/.github/ISSUE_TEMPLATE/i18n.md (deflated 64%)
#   adding: content/transformers/.github/ISSUE_TEMPLATE/bug-report.yml (deflated 61%)
#   adding: content/transformers/.github/ISSUE_TEMPLATE/config.yml (deflated 48%)
#   adding: content/transformers/.github/ISSUE_TEMPLATE/new-model-addition.yml (deflated 58%)
#   adding: content/transformers/.github/ISSUE_TEMPLATE/migration.yml (deflated 62%)
#   adding: content/transformers/README_vi.md (deflated 66%)
#   adding: content/transformers/tests/ (stored 0%)
#   adding: content/transformers/tests/tools/ (stored 0%)
#   adding: content/transformers/tests/tools/test_document_question_answering.py (deflated 66%)
#   adding: content/transformers/tests/tools/test_tools_common.py (deflated 69%)
#   adding: content/transformers/tests/tools/test_translation.py (deflated 69%)
#   adding: content/transformers/tests/tools/test_text_summarization.py (deflated 74%)
#   adding: content/transformers/tests/tools/test_image_captioning.py (deflated 65%)
#   adding: content/transformers/tests/tools/test_python_interpreter.py (deflated 77%)
#   adding: content/transformers/tests/tools/test_text_question_answering.py (deflated 59%)
#   adding: content/transformers/tests/tools/test_agent_types.py (deflated 71%)
#   adding: content/transformers/tests/tools/__init__.py (stored 0%)
#   adding: content/transformers/tests/tools/test_image_segmentation.py (deflated 65%)
#   adding: content/transformers/tests/tools/test_speech_to_text.py (deflated 49%)
#   adding: content/transformers/tests/tools/test_text_to_speech.py (deflated 59%)
#   adding: content/transformers/tests/tools/test_image_question_answering.py (deflated 65%)
#   adding: content/transformers/tests/tools/test_text_classification.py (deflated 61%)
#   adding: content/transformers/tests/fixtures/ (stored 0%)
#   adding: content/transformers/tests/fixtures/vocab.json (deflated 42%)
#   adding: content/transformers/tests/fixtures/test_entity_vocab.json (deflated 29%)
#   adding: content/transformers/tests/fixtures/test_sentencepiece_no_bos.model (deflated 42%)
#   adding: content/transformers/tests/fixtures/sample_text.txt (deflated 48%)
#   adding: content/transformers/tests/fixtures/test_sentencepiece_bpe.model (deflated 42%)
#   adding: content/transformers/tests/fixtures/tests_samples/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/MRPC/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/MRPC/dev.csv (deflated 54%)
#   adding: content/transformers/tests/fixtures/tests_samples/MRPC/dev.tsv (deflated 50%)
#   adding: content/transformers/tests/fixtures/tests_samples/MRPC/train.tsv (deflated 50%)
#   adding: content/transformers/tests/fixtures/tests_samples/MRPC/train.csv (deflated 54%)
#   adding: content/transformers/tests/fixtures/tests_samples/xsum/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/xsum/sample.json (deflated 55%)
#   adding: content/transformers/tests/fixtures/tests_samples/wmt16/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/wmt16/sample.json (deflated 68%)
#   adding: content/transformers/tests/fixtures/tests_samples/SQUAD/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/SQUAD/sample.json (deflated 86%)
#   adding: content/transformers/tests/fixtures/tests_samples/COCO/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/COCO/coco_annotations.txt (deflated 64%)
#   adding: content/transformers/tests/fixtures/tests_samples/COCO/000000039769.png (deflated 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/COCO/000000004016.png (deflated 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/COCO/coco_panoptic_annotations.txt (deflated 63%)
#   adding: content/transformers/tests/fixtures/tests_samples/COCO/coco_panoptic/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/COCO/coco_panoptic/000000039769.png (deflated 2%)
#   adding: content/transformers/tests/fixtures/tests_samples/conll/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/conll/sample.json (deflated 70%)
#   adding: content/transformers/tests/fixtures/tests_samples/swag/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/swag/sample.json (deflated 69%)
#   adding: content/transformers/tests/fixtures/tests_samples/wiki_text/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/wiki_text/wiki_00 (deflated 64%)
#   adding: content/transformers/tests/fixtures/tests_samples/.gitignore (deflated 17%)
#   adding: content/transformers/tests/fixtures/tests_samples/STS-B/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/STS-B/dev.tsv (deflated 68%)
#   adding: content/transformers/tests/fixtures/tests_samples/STS-B/train.tsv (deflated 68%)
#   adding: content/transformers/tests/fixtures/tests_samples/wmt_en_ro/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/wmt_en_ro/val.json (deflated 56%)
#   adding: content/transformers/tests/fixtures/tests_samples/wmt_en_ro/test.json (deflated 60%)
#   adding: content/transformers/tests/fixtures/tests_samples/wmt_en_ro/train.json (deflated 74%)
#   adding: content/transformers/tests/fixtures/tests_samples/GermEval/ (stored 0%)
#   adding: content/transformers/tests/fixtures/tests_samples/GermEval/train.txt (deflated 50%)
#   adding: content/transformers/tests/fixtures/tests_samples/GermEval/labels.txt (deflated 59%)
#   adding: content/transformers/tests/fixtures/tests_samples/GermEval/dev.txt (deflated 50%)
#   adding: content/transformers/tests/fixtures/dummy_feature_extractor_config.json (deflated 27%)
#   adding: content/transformers/tests/fixtures/sample_text_no_unicode.txt (deflated 50%)
#   adding: content/transformers/tests/fixtures/test_sentencepiece_with_bytefallback.model (deflated 43%)
#   adding: content/transformers/tests/fixtures/dummy-config.json (stored 0%)
#   adding: content/transformers/tests/fixtures/add_distilbert_like_config.json (deflated 54%)
#   adding: content/transformers/tests/fixtures/test_sentencepiece.model (deflated 42%)
#   adding: content/transformers/tests/fixtures/preprocessor_config.json (deflated 27%)
#   adding: content/transformers/tests/fixtures/input.txt (deflated 19%)
#   adding: content/transformers/tests/fixtures/test_sentencepiece_bpe_char.model (deflated 42%)
#   adding: content/transformers/tests/fixtures/spiece.model (deflated 49%)
#   adding: content/transformers/tests/fixtures/merges.txt (deflated 6%)
#   adding: content/transformers/tests/fixtures/vocab.txt (deflated 46%)
#   adding: content/transformers/tests/fixtures/empty.txt (stored 0%)
#   adding: content/transformers/tests/test_modeling_utils.py (deflated 84%)
#   adding: content/transformers/tests/utils/ (stored 0%)
#   adding: content/transformers/tests/utils/test_model_output.py (deflated 73%)
#   adding: content/transformers/tests/utils/test_audio_utils.py (deflated 80%)
#   adding: content/transformers/tests/utils/test_hub_utils.py (deflated 69%)
#   adding: content/transformers/tests/utils/test_cli.py (deflated 72%)
#   adding: content/transformers/tests/utils/test_offline.py (deflated 80%)
#   adding: content/transformers/tests/utils/test_dynamic_module_utils.py (deflated 63%)
#   adding: content/transformers/tests/utils/test_generic.py (deflated 82%)
#   adding: content/transformers/tests/utils/test_hf_argparser.py (deflated 77%)
#   adding: content/transformers/tests/utils/test_modeling_tf_core.py (deflated 76%)
#   adding: content/transformers/tests/utils/test_add_new_model_like.py (deflated 89%)
#   adding: content/transformers/tests/utils/test_logging.py (deflated 72%)
#   adding: content/transformers/tests/utils/test_image_utils.py (deflated 85%)
#   adding: content/transformers/tests/utils/test_versions_utils.py (deflated 69%)
#   adding: content/transformers/tests/utils/test_file_utils.py (deflated 69%)
#   adding: content/transformers/tests/utils/test_convert_slow_tokenizer.py (deflated 67%)
#   adding: content/transformers/tests/utils/__init__.py (stored 0%)
#   adding: content/transformers/tests/utils/test_model_card.py (deflated 66%)
#   adding: content/transformers/tests/utils/test_activations.py (deflated 66%)
#   adding: content/transformers/tests/utils/test_backbone_utils.py (deflated 80%)
#   adding: content/transformers/tests/utils/test_doc_samples.py (deflated 68%)
#   adding: content/transformers/tests/utils/test_image_processing_utils.py (deflated 69%)
#   adding: content/transformers/tests/utils/tiny_model_summary.json (deflated 87%)
#   adding: content/transformers/tests/utils/test_skip_decorators.py (deflated 62%)
#   adding: content/transformers/tests/utils/test_activations_tf.py (deflated 60%)
#   adding: content/transformers/tests/sagemaker/ (stored 0%)
#   adding: content/transformers/tests/sagemaker/README.md (deflated 75%)
#   adding: content/transformers/tests/sagemaker/test_single_node_gpu.py (deflated 65%)
#   adding: content/transformers/tests/sagemaker/test_multi_node_data_parallel.py (deflated 67%)
#   adding: content/transformers/tests/sagemaker/scripts/ (stored 0%)
#   adding: content/transformers/tests/sagemaker/scripts/pytorch/ (stored 0%)
#   adding: content/transformers/tests/sagemaker/scripts/pytorch/requirements.txt (deflated 22%)
#   adding: content/transformers/tests/sagemaker/scripts/pytorch/run_glue_model_parallelism.py (deflated 72%)
#   adding: content/transformers/tests/sagemaker/scripts/pytorch/run_ddp.py (deflated 59%)
#   adding: content/transformers/tests/sagemaker/scripts/tensorflow/ (stored 0%)
#   adding: content/transformers/tests/sagemaker/scripts/tensorflow/requirements.txt (deflated 24%)
#   adding: content/transformers/tests/sagemaker/scripts/tensorflow/run_tf.py (deflated 65%)
#   adding: content/transformers/tests/sagemaker/scripts/tensorflow/run_tf_dist.py (deflated 70%)
#   adding: content/transformers/tests/sagemaker/conftest.py (deflated 63%)
#   adding: content/transformers/tests/sagemaker/__init__.py (deflated 20%)
#   adding: content/transformers/tests/sagemaker/test_multi_node_model_parallel.py (deflated 66%)
#   adding: content/transformers/tests/test_image_processing_common.py (deflated 80%)
#   adding: content/transformers/tests/generation/ (stored 0%)
#   adding: content/transformers/tests/generation/test_utils.py (deflated 86%)
#   adding: content/transformers/tests/generation/test_beam_constraints.py (deflated 71%)
#   adding: content/transformers/tests/generation/test_stopping_criteria.py (deflated 78%)
#   adding: content/transformers/tests/generation/test_flax_logits_process.py (deflated 80%)
#   adding: content/transformers/tests/generation/test_tf_utils.py (deflated 74%)
#   adding: content/transformers/tests/generation/test_streamers.py (deflated 75%)
#   adding: content/transformers/tests/generation/test_flax_utils.py (deflated 82%)
#   adding: content/transformers/tests/generation/test_logits_process.py (deflated 84%)
#   adding: content/transformers/tests/generation/test_configuration_utils.py (deflated 78%)
#   adding: content/transformers/tests/generation/__init__.py (stored 0%)
#   adding: content/transformers/tests/generation/test_tf_logits_process.py (deflated 80%)
#   adding: content/transformers/tests/generation/test_framework_agnostic.py (deflated 88%)
#   adding: content/transformers/tests/generation/test_beam_search.py (deflated 85%)
#   adding: content/transformers/tests/test_modeling_tf_utils.py (deflated 82%)
#   adding: content/transformers/tests/test_tokenization_utils.py (deflated 77%)
#   adding: content/transformers/tests/peft_integration/ (stored 0%)
#   adding: content/transformers/tests/peft_integration/test_peft_integration.py (deflated 85%)
#   adding: content/transformers/tests/repo_utils/ (stored 0%)
#   adding: content/transformers/tests/repo_utils/test_check_copies.py (deflated 80%)
#   adding: content/transformers/tests/repo_utils/test_check_dummies.py (deflated 69%)
#   adding: content/transformers/tests/repo_utils/test_get_test_info.py (deflated 77%)
#   adding: content/transformers/tests/repo_utils/test_tests_fetcher.py (deflated 86%)
#   adding: content/transformers/tests/repo_utils/test_check_docstrings.py (deflated 78%)
#   adding: content/transformers/tests/bettertransformer/ (stored 0%)
#   adding: content/transformers/tests/bettertransformer/test_integration.py (deflated 63%)
#   adding: content/transformers/tests/bettertransformer/__init__.py (stored 0%)
#   adding: content/transformers/tests/trainer/ (stored 0%)
#   adding: content/transformers/tests/trainer/test_trainer_utils.py (deflated 81%)
#   adding: content/transformers/tests/trainer/test_trainer_tpu.py (deflated 62%)
#   adding: content/transformers/tests/trainer/test_trainer_seq2seq.py (deflated 70%)
#   adding: content/transformers/tests/trainer/test_trainer_callback.py (deflated 82%)
#   adding: content/transformers/tests/trainer/test_data_collator.py (deflated 93%)
#   adding: content/transformers/tests/trainer/test_trainer.py (deflated 85%)
#   adding: content/transformers/tests/trainer/__init__.py (stored 0%)
#   adding: content/transformers/tests/trainer/test_trainer_distributed.py (deflated 73%)
#   adding: content/transformers/tests/optimization/ (stored 0%)
#   adding: content/transformers/tests/optimization/__init__.py (stored 0%)
#   adding: content/transformers/tests/optimization/test_optimization.py (deflated 70%)
#   adding: content/transformers/tests/optimization/test_optimization_tf.py (deflated 68%)
#   adding: content/transformers/tests/test_cache_utils.py (deflated 80%)
#   adding: content/transformers/tests/test_configuration_common.py (deflated 73%)
#   adding: content/transformers/tests/test_configuration_utils.py (deflated 71%)
#   adding: content/transformers/tests/benchmark/ (stored 0%)
#   adding: content/transformers/tests/benchmark/test_benchmark.py (deflated 86%)
#   adding: content/transformers/tests/benchmark/test_benchmark_tf.py (deflated 84%)
#   adding: content/transformers/tests/benchmark/__init__.py (stored 0%)
#   adding: content/transformers/tests/extended/ (stored 0%)
#   adding: content/transformers/tests/extended/test_trainer_ext.py (deflated 70%)
#   adding: content/transformers/tests/test_processing_common.py (deflated 72%)
#   adding: content/transformers/tests/test_modeling_flax_utils.py (deflated 83%)
#   adding: content/transformers/tests/test_image_transforms.py (deflated 83%)
#   adding: content/transformers/tests/test_pipeline_mixin.py (deflated 79%)
#   adding: content/transformers/tests/__init__.py (stored 0%)
#   adding: content/transformers/tests/test_tokenization_common.py (deflated 87%)
#   adding: content/transformers/tests/pipelines/ (stored 0%)
#   adding: content/transformers/tests/pipelines/test_pipelines_text2text_generation.py (deflated 74%)
#   adding: content/transformers/tests/pipelines/test_pipelines_zero_shot.py (deflated 83%)
#   adding: content/transformers/tests/pipelines/test_pipelines_automatic_speech_recognition.py (deflated 84%)
#   adding: content/transformers/tests/pipelines/test_pipelines_visual_question_answering.py (deflated 78%)
#   adding: content/transformers/tests/pipelines/test_pipelines_feature_extraction.py (deflated 85%)
#   adding: content/transformers/tests/pipelines/test_pipelines_table_question_answering.py (deflated 91%)
#   adding: content/transformers/tests/pipelines/test_pipelines_depth_estimation.py (deflated 65%)
#   adding: content/transformers/tests/pipelines/test_pipelines_zero_shot_object_detection.py (deflated 83%)
#   adding: content/transformers/tests/pipelines/test_pipelines_video_classification.py (deflated 65%)
#   adding: content/transformers/tests/pipelines/test_pipelines_audio_classification.py (deflated 69%)
#   adding: content/transformers/tests/pipelines/test_pipelines_common.py (deflated 80%)
#   adding: content/transformers/tests/pipelines/test_pipelines_zero_shot_audio_classification.py (deflated 69%)
#   adding: content/transformers/tests/pipelines/test_pipelines_translation.py (deflated 77%)
#   adding: content/transformers/tests/pipelines/test_pipelines_image_feature_extraction.py (deflated 76%)
#   adding: content/transformers/tests/pipelines/test_pipelines_zero_shot_image_classification.py (deflated 82%)
#   adding: content/transformers/tests/pipelines/test_pipelines_image_to_image.py (deflated 63%)
#   adding: content/transformers/tests/pipelines/test_pipelines_token_classification.py (deflated 86%)
#   adding: content/transformers/tests/pipelines/test_pipelines_object_detection.py (deflated 83%)
#   adding: content/transformers/tests/pipelines/test_pipelines_conversational.py (deflated 77%)
#   adding: content/transformers/tests/pipelines/__init__.py (stored 0%)
#   adding: content/transformers/tests/pipelines/test_pipelines_document_question_answering.py (deflated 82%)
#   adding: content/transformers/tests/pipelines/test_pipelines_question_answering.py (deflated 77%)
#   adding: content/transformers/tests/pipelines/test_pipelines_text_generation.py (deflated 81%)
#   adding: content/transformers/tests/pipelines/test_pipelines_text_classification.py (deflated 78%)
#   adding: content/transformers/tests/pipelines/test_pipelines_mask_generation.py (deflated 72%)
#   adding: content/transformers/tests/pipelines/test_pipelines_image_to_text.py (deflated 82%)
#   adding: content/transformers/tests/pipelines/test_pipelines_text_to_audio.py (deflated 79%)
#   adding: content/transformers/tests/pipelines/test_pipelines_image_classification.py (deflated 81%)
#   adding: content/transformers/tests/pipelines/test_pipelines_image_segmentation.py (deflated 84%)
#   adding: content/transformers/tests/pipelines/test_pipelines_summarization.py (deflated 65%)
#   adding: content/transformers/tests/pipelines/test_pipelines_fill_mask.py (deflated 84%)
#   adding: content/transformers/tests/quantization/ (stored 0%)
#   adding: content/transformers/tests/quantization/bnb/ (stored 0%)
#   adding: content/transformers/tests/quantization/bnb/README.md (deflated 57%)
#   adding: content/transformers/tests/quantization/bnb/test_mixed_int8.py (deflated 81%)
#   adding: content/transformers/tests/quantization/bnb/test_4bit.py (deflated 77%)
#   adding: content/transformers/tests/quantization/bnb/__init__.py (stored 0%)
#   adding: content/transformers/tests/quantization/autoawq/ (stored 0%)
#   adding: content/transformers/tests/quantization/autoawq/test_awq.py (deflated 77%)
#   adding: content/transformers/tests/quantization/autoawq/__init__.py (stored 0%)
#   adding: content/transformers/tests/quantization/gptq/ (stored 0%)
#   adding: content/transformers/tests/quantization/gptq/__init__.py (stored 0%)
#   adding: content/transformers/tests/quantization/gptq/test_gptq.py (deflated 79%)
#   adding: content/transformers/tests/quantization/quanto_integration/ (stored 0%)
#   adding: content/transformers/tests/quantization/quanto_integration/__init__.py (stored 0%)
#   adding: content/transformers/tests/quantization/quanto_integration/test_quanto.py (deflated 80%)
#   adding: content/transformers/tests/quantization/aqlm_integration/ (stored 0%)
#   adding: content/transformers/tests/quantization/aqlm_integration/test_aqlm.py (deflated 72%)
#   adding: content/transformers/tests/quantization/aqlm_integration/__init__.py (stored 0%)
#   adding: content/transformers/tests/quantization/eetq_integration/ (stored 0%)
#   adding: content/transformers/tests/quantization/eetq_integration/test_eetq.py (deflated 71%)
#   adding: content/transformers/tests/quantization/eetq_integration/__init__.py (stored 0%)
#   adding: content/transformers/tests/test_backbone_common.py (deflated 79%)
#   adding: content/transformers/tests/fsdp/ (stored 0%)
#   adding: content/transformers/tests/fsdp/test_fsdp.py (deflated 71%)
#   adding: content/transformers/tests/tokenization/ (stored 0%)
#   adding: content/transformers/tests/tokenization/test_tokenization_fast.py (deflated 75%)
#   adding: content/transformers/tests/tokenization/test_tokenization_utils.py (deflated 82%)
#   adding: content/transformers/tests/tokenization/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/ (stored 0%)
#   adding: content/transformers/tests/models/udop/ (stored 0%)
#   adding: content/transformers/tests/models/udop/test_tokenization_udop.py (deflated 87%)
#   adding: content/transformers/tests/models/udop/test_modeling_udop.py (deflated 81%)
#   adding: content/transformers/tests/models/udop/test_processor_udop.py (deflated 81%)
#   adding: content/transformers/tests/models/udop/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/videomae/ (stored 0%)
#   adding: content/transformers/tests/models/videomae/test_image_processing_videomae.py (deflated 82%)
#   adding: content/transformers/tests/models/videomae/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/videomae/test_modeling_videomae.py (deflated 76%)
#   adding: content/transformers/tests/models/owlv2/ (stored 0%)
#   adding: content/transformers/tests/models/owlv2/test_image_processor_owlv2.py (deflated 68%)
#   adding: content/transformers/tests/models/owlv2/test_modeling_owlv2.py (deflated 84%)
#   adding: content/transformers/tests/models/owlv2/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/vipllava/ (stored 0%)
#   adding: content/transformers/tests/models/vipllava/test_modeling_vipllava.py (deflated 78%)
#   adding: content/transformers/tests/models/vipllava/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/yoso/ (stored 0%)
#   adding: content/transformers/tests/models/yoso/test_modeling_yoso.py (deflated 81%)
#   adding: content/transformers/tests/models/yoso/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/vivit/ (stored 0%)
#   adding: content/transformers/tests/models/vivit/test_modeling_vivit.py (deflated 74%)
#   adding: content/transformers/tests/models/vivit/test_image_processing_vivit.py (deflated 81%)
#   adding: content/transformers/tests/models/vivit/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/falcon/ (stored 0%)
#   adding: content/transformers/tests/models/falcon/test_modeling_falcon.py (deflated 79%)
#   adding: content/transformers/tests/models/falcon/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/splinter/ (stored 0%)
#   adding: content/transformers/tests/models/splinter/test_modeling_splinter.py (deflated 81%)
#   adding: content/transformers/tests/models/splinter/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/realm/ (stored 0%)
#   adding: content/transformers/tests/models/realm/test_retrieval_realm.py (deflated 74%)
#   adding: content/transformers/tests/models/realm/test_modeling_realm.py (deflated 80%)
#   adding: content/transformers/tests/models/realm/test_tokenization_realm.py (deflated 79%)
#   adding: content/transformers/tests/models/realm/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/git/ (stored 0%)
#   adding: content/transformers/tests/models/git/test_modeling_git.py (deflated 79%)
#   adding: content/transformers/tests/models/git/test_processor_git.py (deflated 72%)
#   adding: content/transformers/tests/models/git/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/persimmon/ (stored 0%)
#   adding: content/transformers/tests/models/persimmon/test_modeling_persimmon.py (deflated 79%)
#   adding: content/transformers/tests/models/persimmon/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/mobilenet_v1/ (stored 0%)
#   adding: content/transformers/tests/models/mobilenet_v1/test_modeling_mobilenet_v1.py (deflated 72%)
#   adding: content/transformers/tests/models/mobilenet_v1/test_image_processing_mobilenet_v1.py (deflated 70%)
#   adding: content/transformers/tests/models/mobilenet_v1/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/unispeech/ (stored 0%)
#   adding: content/transformers/tests/models/unispeech/test_modeling_unispeech.py (deflated 79%)
#   adding: content/transformers/tests/models/unispeech/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/t5/ (stored 0%)
#   adding: content/transformers/tests/models/t5/test_modeling_flax_t5.py (deflated 78%)
#   adding: content/transformers/tests/models/t5/test_tokenization_t5.py (deflated 80%)
#   adding: content/transformers/tests/models/t5/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/t5/test_modeling_tf_t5.py (deflated 74%)
#   adding: content/transformers/tests/models/t5/test_modeling_t5.py (deflated 77%)
#   adding: content/transformers/tests/models/imagegpt/ (stored 0%)
#   adding: content/transformers/tests/models/imagegpt/test_modeling_imagegpt.py (deflated 80%)
#   adding: content/transformers/tests/models/imagegpt/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/imagegpt/test_image_processing_imagegpt.py (deflated 78%)
#   adding: content/transformers/tests/models/layoutxlm/ (stored 0%)
#   adding: content/transformers/tests/models/layoutxlm/test_processor_layoutxlm.py (deflated 81%)
#   adding: content/transformers/tests/models/layoutxlm/test_tokenization_layoutxlm.py (deflated 87%)
#   adding: content/transformers/tests/models/layoutxlm/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/vision_encoder_decoder/ (stored 0%)
#   adding: content/transformers/tests/models/vision_encoder_decoder/test_modeling_tf_vision_encoder_decoder.py (deflated 81%)
#   adding: content/transformers/tests/models/vision_encoder_decoder/test_modeling_flax_vision_encoder_decoder.py (deflated 80%)
#   adding: content/transformers/tests/models/vision_encoder_decoder/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/vision_encoder_decoder/test_modeling_vision_encoder_decoder.py (deflated 86%)
#   adding: content/transformers/tests/models/gpt2/ (stored 0%)
#   adding: content/transformers/tests/models/gpt2/test_modeling_flax_gpt2.py (deflated 80%)
#   adding: content/transformers/tests/models/gpt2/test_modeling_gpt2.py (deflated 83%)
#   adding: content/transformers/tests/models/gpt2/test_tokenization_gpt2.py (deflated 77%)
#   adding: content/transformers/tests/models/gpt2/test_tokenization_gpt2_tf.py (deflated 68%)
#   adding: content/transformers/tests/models/gpt2/test_modeling_tf_gpt2.py (deflated 82%)
#   adding: content/transformers/tests/models/gpt2/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/vit_mae/ (stored 0%)
#   adding: content/transformers/tests/models/vit_mae/test_modeling_vit_mae.py (deflated 73%)
#   adding: content/transformers/tests/models/vit_mae/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/vit_mae/test_modeling_tf_vit_mae.py (deflated 76%)
#   adding: content/transformers/tests/models/bert/ (stored 0%)
#   adding: content/transformers/tests/models/bert/test_tokenization_bert.py (deflated 80%)
#   adding: content/transformers/tests/models/bert/test_modeling_tf_bert.py (deflated 85%)
#   adding: content/transformers/tests/models/bert/test_modeling_bert.py (deflated 83%)
#   adding: content/transformers/tests/models/bert/test_tokenization_bert_tf.py (deflated 68%)
#   adding: content/transformers/tests/models/bert/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/bert/test_modeling_flax_bert.py (deflated 72%)
#   adding: content/transformers/tests/models/bart/ (stored 0%)
#   adding: content/transformers/tests/models/bart/test_tokenization_bart.py (deflated 73%)
#   adding: content/transformers/tests/models/bart/test_modeling_bart.py (deflated 80%)
#   adding: content/transformers/tests/models/bart/test_modeling_flax_bart.py (deflated 71%)
#   adding: content/transformers/tests/models/bart/test_modeling_tf_bart.py (deflated 80%)
#   adding: content/transformers/tests/models/bart/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/idefics/ (stored 0%)
#   adding: content/transformers/tests/models/idefics/test_modeling_idefics.py (deflated 81%)
#   adding: content/transformers/tests/models/idefics/test_image_processing_idefics.py (deflated 71%)
#   adding: content/transformers/tests/models/idefics/test_processor_idefics.py (deflated 77%)
#   adding: content/transformers/tests/models/idefics/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/autoformer/ (stored 0%)
#   adding: content/transformers/tests/models/autoformer/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/autoformer/test_modeling_autoformer.py (deflated 78%)
#   adding: content/transformers/tests/models/squeezebert/ (stored 0%)
#   adding: content/transformers/tests/models/squeezebert/test_modeling_squeezebert.py (deflated 79%)
#   adding: content/transformers/tests/models/squeezebert/test_tokenization_squeezebert.py (deflated 59%)
#   adding: content/transformers/tests/models/squeezebert/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/markuplm/ (stored 0%)
#   adding: content/transformers/tests/models/markuplm/test_processor_markuplm.py (deflated 89%)
#   adding: content/transformers/tests/models/markuplm/test_feature_extraction_markuplm.py (deflated 64%)
#   adding: content/transformers/tests/models/markuplm/test_modeling_markuplm.py (deflated 78%)
#   adding: content/transformers/tests/models/markuplm/test_tokenization_markuplm.py (deflated 92%)
#   adding: content/transformers/tests/models/markuplm/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/speech_to_text/ (stored 0%)
#   adding: content/transformers/tests/models/speech_to_text/test_modeling_tf_speech_to_text.py (deflated 79%)
#   adding: content/transformers/tests/models/speech_to_text/test_modeling_speech_to_text.py (deflated 80%)
#   adding: content/transformers/tests/models/speech_to_text/test_tokenization_speech_to_text.py (deflated 74%)
#   adding: content/transformers/tests/models/speech_to_text/test_feature_extraction_speech_to_text.py (deflated 79%)
#   adding: content/transformers/tests/models/speech_to_text/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/speech_to_text/test_processor_speech_to_text.py (deflated 74%)
#   adding: content/transformers/tests/models/hubert/ (stored 0%)
#   adding: content/transformers/tests/models/hubert/test_modeling_tf_hubert.py (deflated 82%)
#   adding: content/transformers/tests/models/hubert/test_modeling_hubert.py (deflated 82%)
#   adding: content/transformers/tests/models/hubert/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/ibert/ (stored 0%)
#   adding: content/transformers/tests/models/ibert/test_modeling_ibert.py (deflated 82%)
#   adding: content/transformers/tests/models/ibert/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/pix2struct/ (stored 0%)
#   adding: content/transformers/tests/models/pix2struct/test_image_processing_pix2struct.py (deflated 85%)
#   adding: content/transformers/tests/models/pix2struct/test_modeling_pix2struct.py (deflated 82%)
#   adding: content/transformers/tests/models/pix2struct/test_processor_pix2struct.py (deflated 76%)
#   adding: content/transformers/tests/models/pix2struct/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/xmod/ (stored 0%)
#   adding: content/transformers/tests/models/xmod/test_modeling_xmod.py (deflated 83%)
#   adding: content/transformers/tests/models/xmod/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/seamless_m4t_v2/ (stored 0%)
#   adding: content/transformers/tests/models/seamless_m4t_v2/test_modeling_seamless_m4t_v2.py (deflated 82%)
#   adding: content/transformers/tests/models/seamless_m4t_v2/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/bros/ (stored 0%)
#   adding: content/transformers/tests/models/bros/test_modeling_bros.py (deflated 79%)
#   adding: content/transformers/tests/models/bros/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/cvt/ (stored 0%)
#   adding: content/transformers/tests/models/cvt/test_modeling_cvt.py (deflated 72%)
#   adding: content/transformers/tests/models/cvt/test_modeling_tf_cvt.py (deflated 73%)
#   adding: content/transformers/tests/models/cvt/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/gptj/ (stored 0%)
#   adding: content/transformers/tests/models/gptj/test_modeling_gptj.py (deflated 79%)
#   adding: content/transformers/tests/models/gptj/test_modeling_tf_gptj.py (deflated 78%)
#   adding: content/transformers/tests/models/gptj/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/gptj/test_modeling_flax_gptj.py (deflated 79%)
#   adding: content/transformers/tests/models/wavlm/ (stored 0%)
#   adding: content/transformers/tests/models/wavlm/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/wavlm/test_modeling_wavlm.py (deflated 78%)
#   adding: content/transformers/tests/models/audio_spectrogram_transformer/ (stored 0%)
#   adding: content/transformers/tests/models/audio_spectrogram_transformer/test_feature_extraction_audio_spectrogram_transformer.py (deflated 71%)
#   adding: content/transformers/tests/models/audio_spectrogram_transformer/test_modeling_audio_spectrogram_transformer.py (deflated 69%)
#   adding: content/transformers/tests/models/audio_spectrogram_transformer/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/levit/ (stored 0%)
#   adding: content/transformers/tests/models/levit/test_modeling_levit.py (deflated 76%)
#   adding: content/transformers/tests/models/levit/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/levit/test_image_processing_levit.py (deflated 71%)
#   adding: content/transformers/tests/models/beit/ (stored 0%)
#   adding: content/transformers/tests/models/beit/test_modeling_flax_beit.py (deflated 75%)
#   adding: content/transformers/tests/models/beit/test_modeling_beit.py (deflated 78%)
#   adding: content/transformers/tests/models/beit/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/beit/test_image_processing_beit.py (deflated 80%)
#   adding: content/transformers/tests/models/rwkv/ (stored 0%)
#   adding: content/transformers/tests/models/rwkv/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/rwkv/test_modeling_rwkv.py (deflated 78%)
#   adding: content/transformers/tests/models/gpt_neox/ (stored 0%)
#   adding: content/transformers/tests/models/gpt_neox/test_modeling_gpt_neox.py (deflated 78%)
#   adding: content/transformers/tests/models/gpt_neox/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/depth_anything/ (stored 0%)
#   adding: content/transformers/tests/models/depth_anything/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/depth_anything/test_modeling_depth_anything.py (deflated 73%)
#   adding: content/transformers/tests/models/bartpho/ (stored 0%)
#   adding: content/transformers/tests/models/bartpho/test_tokenization_bartpho.py (deflated 58%)
#   adding: content/transformers/tests/models/bartpho/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/deberta/ (stored 0%)
#   adding: content/transformers/tests/models/deberta/test_tokenization_deberta.py (deflated 73%)
#   adding: content/transformers/tests/models/deberta/test_modeling_deberta.py (deflated 78%)
#   adding: content/transformers/tests/models/deberta/test_modeling_tf_deberta.py (deflated 78%)
#   adding: content/transformers/tests/models/deberta/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/layoutlm/ (stored 0%)
#   adding: content/transformers/tests/models/layoutlm/test_modeling_tf_layoutlm.py (deflated 78%)
#   adding: content/transformers/tests/models/layoutlm/test_modeling_layoutlm.py (deflated 78%)
#   adding: content/transformers/tests/models/layoutlm/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/layoutlm/test_tokenization_layoutlm.py (deflated 57%)
#   adding: content/transformers/tests/models/swin2sr/ (stored 0%)
#   adding: content/transformers/tests/models/swin2sr/test_modeling_swin2sr.py (deflated 74%)
#   adding: content/transformers/tests/models/swin2sr/test_image_processing_swin2sr.py (deflated 78%)
#   adding: content/transformers/tests/models/swin2sr/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/convnextv2/ (stored 0%)
#   adding: content/transformers/tests/models/convnextv2/test_modeling_tf_convnextv2.py (deflated 73%)
#   adding: content/transformers/tests/models/convnextv2/test_modeling_convnextv2.py (deflated 75%)
#   adding: content/transformers/tests/models/convnextv2/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/funnel/ (stored 0%)
#   adding: content/transformers/tests/models/funnel/test_modeling_tf_funnel.py (deflated 83%)
#   adding: content/transformers/tests/models/funnel/test_modeling_funnel.py (deflated 82%)
#   adding: content/transformers/tests/models/funnel/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/funnel/test_tokenization_funnel.py (deflated 62%)
#   adding: content/transformers/tests/models/univnet/ (stored 0%)
#   adding: content/transformers/tests/models/univnet/test_feature_extraction_univnet.py (deflated 78%)
#   adding: content/transformers/tests/models/univnet/test_modeling_univnet.py (deflated 74%)
#   adding: content/transformers/tests/models/univnet/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/rembert/ (stored 0%)
#   adding: content/transformers/tests/models/rembert/test_modeling_rembert.py (deflated 81%)
#   adding: content/transformers/tests/models/rembert/test_modeling_tf_rembert.py (deflated 84%)
#   adding: content/transformers/tests/models/rembert/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/rembert/test_tokenization_rembert.py (deflated 75%)
#   adding: content/transformers/tests/models/led/ (stored 0%)
#   adding: content/transformers/tests/models/led/test_modeling_tf_led.py (deflated 75%)
#   adding: content/transformers/tests/models/led/test_modeling_led.py (deflated 71%)
#   adding: content/transformers/tests/models/led/test_tokenization_led.py (deflated 74%)
#   adding: content/transformers/tests/models/led/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/resnet/ (stored 0%)
#   adding: content/transformers/tests/models/resnet/test_modeling_flax_resnet.py (deflated 71%)
#   adding: content/transformers/tests/models/resnet/test_modeling_tf_resnet.py (deflated 71%)
#   adding: content/transformers/tests/models/resnet/test_modeling_resnet.py (deflated 74%)
#   adding: content/transformers/tests/models/resnet/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/bridgetower/ (stored 0%)
#   adding: content/transformers/tests/models/bridgetower/test_image_processing_bridgetower.py (deflated 69%)
#   adding: content/transformers/tests/models/bridgetower/test_modeling_bridgetower.py (deflated 81%)
#   adding: content/transformers/tests/models/bridgetower/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/vilt/ (stored 0%)
#   adding: content/transformers/tests/models/vilt/test_modeling_vilt.py (deflated 81%)
#   adding: content/transformers/tests/models/vilt/test_image_processing_vilt.py (deflated 71%)
#   adding: content/transformers/tests/models/vilt/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/dpr/ (stored 0%)
#   adding: content/transformers/tests/models/dpr/test_tokenization_dpr.py (deflated 71%)
#   adding: content/transformers/tests/models/dpr/test_modeling_tf_dpr.py (deflated 76%)
#   adding: content/transformers/tests/models/dpr/test_modeling_dpr.py (deflated 77%)
#   adding: content/transformers/tests/models/dpr/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/marian/ (stored 0%)
#   adding: content/transformers/tests/models/marian/test_tokenization_marian.py (deflated 72%)
#   adding: content/transformers/tests/models/marian/test_modeling_tf_marian.py (deflated 70%)
#   adding: content/transformers/tests/models/marian/test_modeling_flax_marian.py (deflated 76%)
#   adding: content/transformers/tests/models/marian/test_modeling_marian.py (deflated 78%)
#   adding: content/transformers/tests/models/marian/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/luke/ (stored 0%)
#   adding: content/transformers/tests/models/luke/test_modeling_luke.py (deflated 86%)
#   adding: content/transformers/tests/models/luke/test_tokenization_luke.py (deflated 88%)
#   adding: content/transformers/tests/models/luke/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/oneformer/ (stored 0%)
#   adding: content/transformers/tests/models/oneformer/test_modeling_oneformer.py (deflated 78%)
#   adding: content/transformers/tests/models/oneformer/test_image_processing_oneformer.py (deflated 78%)
#   adding: content/transformers/tests/models/oneformer/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/oneformer/test_processor_oneformer.py (deflated 85%)
#   adding: content/transformers/tests/models/starcoder2/ (stored 0%)
#   adding: content/transformers/tests/models/starcoder2/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/starcoder2/test_modeling_starcoder2.py (deflated 81%)
#   adding: content/transformers/tests/models/vits/ (stored 0%)
#   adding: content/transformers/tests/models/vits/test_modeling_vits.py (deflated 75%)
#   adding: content/transformers/tests/models/vits/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/vits/test_tokenization_vits.py (deflated 80%)
#   adding: content/transformers/tests/models/siglip/ (stored 0%)
#   adding: content/transformers/tests/models/siglip/test_modeling_siglip.py (deflated 82%)
#   adding: content/transformers/tests/models/siglip/test_image_processor_siglip.py (deflated 71%)
#   adding: content/transformers/tests/models/siglip/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/siglip/test_tokenization_siglip.py (deflated 79%)
#   adding: content/transformers/tests/models/bloom/ (stored 0%)
#   adding: content/transformers/tests/models/bloom/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/bloom/test_modeling_bloom.py (deflated 80%)
#   adding: content/transformers/tests/models/bloom/test_tokenization_bloom.py (deflated 71%)
#   adding: content/transformers/tests/models/bloom/test_modeling_flax_bloom.py (deflated 73%)
#   adding: content/transformers/tests/models/dbrx/ (stored 0%)
#   adding: content/transformers/tests/models/dbrx/test_modeling_dbrx.py (deflated 76%)
#   adding: content/transformers/tests/models/dbrx/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/glpn/ (stored 0%)
#   adding: content/transformers/tests/models/glpn/test_modeling_glpn.py (deflated 77%)
#   adding: content/transformers/tests/models/glpn/test_image_processing_glpn.py (deflated 78%)
#   adding: content/transformers/tests/models/glpn/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/blenderbot/ (stored 0%)
#   adding: content/transformers/tests/models/blenderbot/test_modeling_blenderbot.py (deflated 79%)
#   adding: content/transformers/tests/models/blenderbot/test_modeling_flax_blenderbot.py (deflated 78%)
#   adding: content/transformers/tests/models/blenderbot/test_tokenization_blenderbot.py (deflated 66%)
#   adding: content/transformers/tests/models/blenderbot/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/blenderbot/test_modeling_tf_blenderbot.py (deflated 72%)
#   adding: content/transformers/tests/models/wav2vec2_conformer/ (stored 0%)
#   adding: content/transformers/tests/models/wav2vec2_conformer/test_modeling_wav2vec2_conformer.py (deflated 82%)
#   adding: content/transformers/tests/models/wav2vec2_conformer/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/seggpt/ (stored 0%)
#   adding: content/transformers/tests/models/seggpt/test_image_processing_seggpt.py (deflated 78%)
#   adding: content/transformers/tests/models/seggpt/test_modeling_seggpt.py (deflated 76%)
#   adding: content/transformers/tests/models/seggpt/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/megatron_gpt2/ (stored 0%)
#   adding: content/transformers/tests/models/megatron_gpt2/test_modeling_megatron_gpt2.py (deflated 57%)
#   adding: content/transformers/tests/models/megatron_gpt2/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/musicgen_melody/ (stored 0%)
#   adding: content/transformers/tests/models/musicgen_melody/test_feature_extraction_musicgen_melody.py (deflated 75%)
#   adding: content/transformers/tests/models/musicgen_melody/test_processor_musicgen_melody.py (deflated 74%)
#   adding: content/transformers/tests/models/musicgen_melody/test_modeling_musicgen_melody.py (deflated 86%)
#   adding: content/transformers/tests/models/musicgen_melody/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/mamba/ (stored 0%)
#   adding: content/transformers/tests/models/mamba/test_modeling_mamba.py (deflated 77%)
#   adding: content/transformers/tests/models/mamba/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/albert/ (stored 0%)
#   adding: content/transformers/tests/models/albert/test_modeling_flax_albert.py (deflated 70%)
#   adding: content/transformers/tests/models/albert/test_modeling_tf_albert.py (deflated 79%)
#   adding: content/transformers/tests/models/albert/test_modeling_albert.py (deflated 80%)
#   adding: content/transformers/tests/models/albert/test_tokenization_albert.py (deflated 75%)
#   adding: content/transformers/tests/models/albert/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/superpoint/ (stored 0%)
#   adding: content/transformers/tests/models/superpoint/test_image_processing_superpoint.py (deflated 69%)
#   adding: content/transformers/tests/models/superpoint/test_modeling_superpoint.py (deflated 75%)
#   adding: content/transformers/tests/models/superpoint/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/recurrent_gemma/ (stored 0%)
#   adding: content/transformers/tests/models/recurrent_gemma/test_modeling_recurrent_gemma.py (deflated 75%)
#   adding: content/transformers/tests/models/recurrent_gemma/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/xlnet/ (stored 0%)
#   adding: content/transformers/tests/models/xlnet/test_modeling_xlnet.py (deflated 81%)
#   adding: content/transformers/tests/models/xlnet/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/xlnet/test_tokenization_xlnet.py (deflated 80%)
#   adding: content/transformers/tests/models/xlnet/test_modeling_tf_xlnet.py (deflated 79%)
#   adding: content/transformers/tests/models/mt5/ (stored 0%)
#   adding: content/transformers/tests/models/mt5/test_modeling_flax_mt5.py (deflated 56%)
#   adding: content/transformers/tests/models/mt5/test_modeling_tf_mt5.py (deflated 54%)
#   adding: content/transformers/tests/models/mt5/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/mt5/test_modeling_mt5.py (deflated 82%)
#   adding: content/transformers/tests/models/conditional_detr/ (stored 0%)
#   adding: content/transformers/tests/models/conditional_detr/test_modeling_conditional_detr.py (deflated 78%)
#   adding: content/transformers/tests/models/conditional_detr/test_image_processing_conditional_detr.py (deflated 83%)
#   adding: content/transformers/tests/models/conditional_detr/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/camembert/ (stored 0%)
#   adding: content/transformers/tests/models/camembert/test_modeling_tf_camembert.py (deflated 50%)
#   adding: content/transformers/tests/models/camembert/test_modeling_camembert.py (deflated 52%)
#   adding: content/transformers/tests/models/camembert/__init__.py (stored 0%)
#   adding: content/transformers/tests/models/camembert/test_tokenization_camembert.py (deflated 73%)
#   adding: content/transformers/tests/models/gptsan_japanese/ (stored 0%)
#   adding: content/transformers/tests/models/gptsan_japanese/test_modeling_gptsan_japanese.py (deflated 73%)
#   adding: content/transformers/tests/models/gptsan_japanese/__init__.py (stored 0%)
# ...
#   adding: content/transformers/build/lib/transformers/models/speech_encoder_decoder/__init__.py (deflated 64%)
#   adding: content/transformers/build/lib/transformers/models/mvp/ (stored 0%)
#   adding: content/transformers/build/lib/transformers/models/mvp/tokenization_mvp.py (deflated 68%)
#   adding: content/transformers/build/lib/transformers/models/mvp/tokenization_mvp_fast.py (deflated 69%)
#   adding: content/transformers/build/lib/transformers/models/mvp/__init__.py (deflated 64%)
#   adding: content/transformers/build/lib/transformers/models/mvp/configuration_mvp.py (deflated 70%)
#   adding: content/transformers/build/lib/transformers/models/mvp/modeling_mvp.py (deflated 83%)
#   adding: content/transformers/build/lib/transformers/models/swiftformer/ (stored 0%)
#   adding: content/transformers/build/lib/transformers/models/swiftformer/modeling_tf_swiftformer.py (deflated 81%)
#   adding: content/transformers/build/lib/transformers/models/swiftformer/modeling_swiftformer.py (deflated 75%)
#   adding: content/transformers/build/lib/transformers/models/swiftformer/convert_swiftformer_original_to_hf.py (deflated 63%)
#   adding: content/transformers/build/lib/transformers/models/swiftformer/__init__.py (deflated 68%)
#   adding: content/transformers/build/lib/transformers/models/swiftformer/configuration_swiftformer.py (deflated 65%)
#   adding: content/transformers/build/lib/transformers/models/megatron_bert/ (stored 0%)
#   adding: content/transformers/build/lib/transformers/models/megatron_bert/modeling_megatron_bert.py (deflated 83%)
#   adding: content/transformers/build/lib/transformers/models/megatron_bert/convert_megatron_bert_checkpoint.py (deflated 71%)
#   adding: content/transformers/build/lib/transformers/models/megatron_bert/__init__.py (deflated 64%)
#   adding: content/transformers/build/lib/transformers/models/megatron_bert/configuration_megatron_bert.py (deflated 65%)
#   adding: content/transformers/build/lib/transformers/models/visual_bert/ (stored 0%)
#   adding: content/transformers/build/lib/transformers/models/visual_bert/convert_visual_bert_original_pytorch_checkpoint_to_pytorch.py (deflated 66%)
#   adding: content/transformers/build/lib/transformers/models/visual_bert/__init__.py (deflated 61%)
#   adding: content/transformers/build/lib/transformers/models/visual_bert/modeling_visual_bert.py (deflated 83%)
#   adding: content/transformers/build/lib/transformers/models/visual_bert/configuration_visual_bert.py (deflated 68%)
#   adding: content/transformers/build/lib/transformers/models/barthez/ (stored 0%)
#   adding: content/transformers/build/lib/transformers/models/barthez/tokenization_barthez_fast.py (deflated 67%)
#   adding: content/transformers/build/lib/transformers/models/barthez/__init__.py (deflated 63%)
#   adding: content/transformers/build/lib/transformers/models/barthez/tokenization_barthez.py (deflated 69%)
#   adding: content/transformers/build/lib/transformers/models/m2m_100/ (stored 0%)
#   adding: content/transformers/build/lib/transformers/models/m2m_100/convert_m2m100_original_checkpoint_to_pytorch.py (deflated 61%)
#   adding: content/transformers/build/lib/transformers/models/m2m_100/configuration_m2m_100.py (deflated 72%)
#   adding: content/transformers/build/lib/transformers/models/m2m_100/tokenization_m2m_100.py (deflated 69%)
#   adding: content/transformers/build/lib/transformers/models/m2m_100/modeling_m2m_100.py (deflated 82%)
#   adding: content/transformers/build/lib/transformers/models/m2m_100/__init__.py (deflated 58%)
#   adding: content/transformers/build/lib/transformers/models/herbert/ (stored 0%)
#   adding: content/transformers/build/lib/transformers/models/herbert/tokenization_herbert.py (deflated 73%)
#   adding: content/transformers/build/lib/transformers/models/herbert/tokenization_herbert_fast.py (deflated 67%)
#   adding: content/transformers/build/lib/transformers/models/herbert/__init__.py (deflated 55%)
#   adding: content/transformers/build/lib/transformers/models/altclip/ (stored 0%)
#   adding: content/transformers/build/lib/transformers/models/altclip/configuration_altclip.py (deflated 77%)
#   adding: content/transformers/build/lib/transformers/models/altclip/processing_altclip.py (deflated 66%)
#   adding: content/transformers/build/lib/transformers/models/altclip/modeling_altclip.py (deflated 82%)
#   adding: content/transformers/build/lib/transformers/models/altclip/__init__.py (deflated 60%)
#   adding: content/transformers/build/lib/transformers/models/maskformer/ (stored 0%)
#   adding: content/transformers/build/lib/transformers/models/maskformer/modeling_maskformer.py (deflated 81%)
#   adding: content/transformers/build/lib/transformers/models/maskformer/configuration_maskformer.py (deflated 70%)
#   adding: content/transformers/build/lib/transformers/models/maskformer/configuration_maskformer_swin.py (deflated 67%)
#   adding: content/transformers/build/lib/transformers/models/maskformer/convert_maskformer_resnet_to_pytorch.py (deflated 80%)
#   adding: content/transformers/build/lib/transformers/models/maskformer/feature_extraction_maskformer.py (deflated 46%)
#   adding: content/transformers/build/lib/transformers/models/maskformer/convert_maskformer_original_pytorch_checkpoint_to_pytorch.py (deflated 79%)
#   adding: content/transformers/build/lib/transformers/models/maskformer/convert_maskformer_swin_to_pytorch.py (deflated 80%)
#   adding: content/transformers/build/lib/transformers/models/maskformer/image_processing_maskformer.py (deflated 79%)
#   adding: content/transformers/build/lib/transformers/models/maskformer/__init__.py (deflated 68%)
#   adding: content/transformers/build/lib/transformers/models/maskformer/modeling_maskformer_swin.py (deflated 79%)
#   adding: content/transformers/build/lib/transformers/models/mega/ (stored 0%)
#   adding: content/transformers/build/lib/transformers/models/mega/modeling_mega.py (deflated 81%)
#   adding: content/transformers/build/lib/transformers/models/mega/convert_mega_original_pytorch_checkpoint_to_pytorch.py (deflated 68%)
#   adding: content/transformers/build/lib/transformers/models/mega/configuration_mega.py (deflated 72%)
#   adding: content/transformers/build/lib/transformers/models/mega/__init__.py (deflated 60%)
#   adding: content/transformers/build/lib/transformers/image_utils.py (deflated 75%)
#   adding: content/transformers/build/lib/transformers/integrations/ (stored 0%)
#   adding: content/transformers/build/lib/transformers/integrations/bitsandbytes.py (deflated 72%)
#   adding: content/transformers/build/lib/transformers/integrations/eetq.py (deflated 63%)
#   adding: content/transformers/build/lib/transformers/integrations/peft.py (deflated 76%)
#   adding: content/transformers/build/lib/transformers/integrations/tpu.py (deflated 49%)
#   adding: content/transformers/build/lib/transformers/integrations/__init__.py (deflated 72%)
#   adding: content/transformers/build/lib/transformers/integrations/deepspeed.py (deflated 69%)
#   adding: content/transformers/build/lib/transformers/integrations/quanto.py (deflated 67%)
#   adding: content/transformers/build/lib/transformers/integrations/awq.py (deflated 75%)
#   adding: content/transformers/build/lib/transformers/integrations/integration_utils.py (deflated 78%)
#   adding: content/transformers/build/lib/transformers/integrations/aqlm.py (deflated 65%)
#   adding: content/transformers/build/lib/transformers/convert_slow_tokenizers_checkpoints_to_fast.py (deflated 67%)
#   adding: content/transformers/build/bdist.linux-x86_64/ (stored 0%)
#   adding: content/transformers/pyproject.toml (deflated 46%)
#   adding: content/transformers/hubconf.py (deflated 84%)
#   adding: content/transformers/templates/ (stored 0%)
#   adding: content/transformers/templates/adding_a_new_model/ (stored 0%)
#   adding: content/transformers/templates/adding_a_new_model/README.md (deflated 41%)
#   adding: content/transformers/templates/adding_a_new_model/open_model_proposals/ (stored 0%)
#   adding: content/transformers/templates/adding_a_new_model/open_model_proposals/README.md (deflated 2%)
#   adding: content/transformers/templates/adding_a_new_model/open_model_proposals/ADD_BIG_BIRD.md (deflated 66%)
#   adding: content/transformers/templates/adding_a_new_model/ADD_NEW_MODEL_PROPOSAL_TEMPLATE.md (deflated 67%)
#   adding: content/transformers/templates/adding_a_new_example_script/ (stored 0%)
#   adding: content/transformers/templates/adding_a_new_example_script/{{cookiecutter.directory_name}}/ (stored 0%)
#   adding: content/transformers/templates/adding_a_new_example_script/{{cookiecutter.directory_name}}/run_{{cookiecutter.example_shortcut}}.py (deflated 78%)
#   adding: content/transformers/templates/adding_a_new_example_script/README.md (deflated 47%)
#   adding: content/transformers/templates/adding_a_new_example_script/cookiecutter.json (deflated 40%)
#   adding: content/transformers/templates/adding_a_missing_tokenization_test/ (stored 0%)
#   adding: content/transformers/templates/adding_a_missing_tokenization_test/README.md (deflated 46%)
#   adding: content/transformers/templates/adding_a_missing_tokenization_test/cookiecutter-template-{{cookiecutter.modelname}}/ (stored 0%)
#   adding: content/transformers/templates/adding_a_missing_tokenization_test/cookiecutter-template-{{cookiecutter.modelname}}/test_tokenization_{{cookiecutter.lowercase_modelname}}.py (deflated 69%)
#   adding: content/transformers/templates/adding_a_missing_tokenization_test/cookiecutter.json (deflated 48%)
#   adding: content/transformers/docker/ (stored 0%)
#   adding: content/transformers/docker/transformers-quantization-latest-gpu/ (stored 0%)
#   adding: content/transformers/docker/transformers-quantization-latest-gpu/Dockerfile (deflated 57%)
#   adding: content/transformers/docker/transformers-tensorflow-gpu/ (stored 0%)
#   adding: content/transformers/docker/transformers-tensorflow-gpu/Dockerfile (deflated 48%)
#   adding: content/transformers/docker/transformers-doc-builder/ (stored 0%)
#   adding: content/transformers/docker/transformers-doc-builder/Dockerfile (deflated 55%)
#   adding: content/transformers/docker/transformers-pytorch-tpu/ (stored 0%)
#   adding: content/transformers/docker/transformers-pytorch-tpu/docker-entrypoint.sh (deflated 24%)
#   adding: content/transformers/docker/transformers-pytorch-tpu/dataset.yaml (deflated 56%)
#   adding: content/transformers/docker/transformers-pytorch-tpu/bert-base-cased.jsonnet (deflated 48%)
#   adding: content/transformers/docker/transformers-pytorch-tpu/Dockerfile (deflated 65%)
#   adding: content/transformers/docker/transformers-past-gpu/ (stored 0%)
#   adding: content/transformers/docker/transformers-past-gpu/Dockerfile (deflated 56%)
#   adding: content/transformers/docker/transformers-all-latest-gpu/ (stored 0%)
#   adding: content/transformers/docker/transformers-all-latest-gpu/Dockerfile (deflated 57%)
#   adding: content/transformers/docker/transformers-gpu/ (stored 0%)
#   adding: content/transformers/docker/transformers-gpu/Dockerfile (deflated 54%)
#   adding: content/transformers/docker/transformers-pytorch-gpu/ (stored 0%)
#   adding: content/transformers/docker/transformers-pytorch-gpu/Dockerfile (deflated 58%)
#   adding: content/transformers/docker/transformers-pytorch-deepspeed-amd-gpu/ (stored 0%)
#   adding: content/transformers/docker/transformers-pytorch-deepspeed-amd-gpu/Dockerfile (deflated 50%)
#   adding: content/transformers/docker/transformers-pytorch-deepspeed-latest-gpu/ (stored 0%)
#   adding: content/transformers/docker/transformers-pytorch-deepspeed-latest-gpu/Dockerfile (deflated 56%)
#   adding: content/transformers/docker/transformers-pytorch-deepspeed-nightly-gpu/ (stored 0%)
#   adding: content/transformers/docker/transformers-pytorch-deepspeed-nightly-gpu/Dockerfile (deflated 59%)
#   adding: content/transformers/docker/transformers-pytorch-amd-gpu/ (stored 0%)
#   adding: content/transformers/docker/transformers-pytorch-amd-gpu/Dockerfile (deflated 49%)
#   adding: content/transformers/README_ja.md (deflated 63%)
#   adding: content/transformers/Makefile (deflated 65%)
#   adding: content/layout_lm_tutorial/ (stored 0%)
#   adding: content/layout_lm_tutorial/README.md (stored 0%)
#   adding: content/layout_lm_tutorial/layoutlm_preprocess.py (deflated 72%)
#   adding: content/layout_lm_tutorial/.git/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/description (deflated 14%)
#   adding: content/layout_lm_tutorial/.git/logs/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/logs/refs/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/logs/refs/remotes/origin/HEAD (deflated 25%)
#   adding: content/layout_lm_tutorial/.git/logs/refs/heads/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/logs/refs/heads/main (deflated 25%)
#   adding: content/layout_lm_tutorial/.git/logs/HEAD (deflated 25%)
#   adding: content/layout_lm_tutorial/.git/packed-refs (deflated 8%)
#   adding: content/layout_lm_tutorial/.git/index (deflated 21%)
#   adding: content/layout_lm_tutorial/.git/info/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/info/exclude (deflated 28%)
#   adding: content/layout_lm_tutorial/.git/objects/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/objects/info/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/objects/pack/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/objects/pack/pack-e7e32acb581384b7478b7c5f77601065846526a6.pack (stored 0%)
#   adding: content/layout_lm_tutorial/.git/objects/pack/pack-e7e32acb581384b7478b7c5f77601065846526a6.idx (deflated 80%)
#   adding: content/layout_lm_tutorial/.git/hooks/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/layout_lm_tutorial/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/layout_lm_tutorial/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/layout_lm_tutorial/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/layout_lm_tutorial/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/layout_lm_tutorial/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/layout_lm_tutorial/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/layout_lm_tutorial/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/layout_lm_tutorial/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/layout_lm_tutorial/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/layout_lm_tutorial/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/layout_lm_tutorial/.git/hooks/update.sample (deflated 68%)
#   adding: content/layout_lm_tutorial/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/layout_lm_tutorial/.git/branches/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/refs/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/refs/tags/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/refs/remotes/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/layout_lm_tutorial/.git/refs/heads/ (stored 0%)
#   adding: content/layout_lm_tutorial/.git/refs/heads/main (stored 0%)
#   adding: content/layout_lm_tutorial/.git/config (deflated 32%)
#   adding: content/layout_lm_tutorial/.git/HEAD (stored 0%)
#   adding: content/layout_lm_tutorial/__pycache__/ (stored 0%)
#   adding: content/layout_lm_tutorial/__pycache__/layoutlm_preprocess.cpython-310.pyc (deflated 45%)
#   adding: content/sample_data/ (stored 0%)
#   adding: content/sample_data/README.md (deflated 42%)
#   adding: content/sample_data/anscombe.json (deflated 83%)
#   adding: content/sample_data/mnist_train_small.csv (deflated 88%)
#   adding: content/sample_data/california_housing_test.csv (deflated 76%)
#   adding: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/sample_data/california_housing_train.csv (deflated 79%)

# %%
from google.colab import files
files.download("/content/file.zip")
